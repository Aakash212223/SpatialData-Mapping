# %% [markdown]
# # 📝 Foundations Quiz
#
# This quiz covers material from the **Foundations** notebooks (01–08).
# Answer each question in the provided cell. Some questions require code, others are written answers.

# %% [markdown]
# ## Q1. Magics
# What does `%whos` display? Write your answer below.

# %% [markdown]
# *Your Answer:* %whos displays all variables currently defined in the notebook with their type, size, and value.

# %% [markdown]
# ## Q2. Markdown
# Create a Markdown cell with a heading `## My Hobbies` and a bullet list of at least 3 hobbies.

# %% [markdown]
# ## My Hobbies
# - Trading
# - Programming
# - Learning AI

# %% [markdown]
# *Your Answer:*

# %% [markdown]
# ## Q3. Files and Paths
# Use `%pwd` to print your current working directory.

# %%
# %pwd
# Out:
# '/Users/aakash/SpatialData-Mapping/Assignments/01-Python_Foundations/04-Foundations/Assessments'

# %% [markdown]
# ## Q4. File I/O
# Write Python code that saves `Hello World` to a file called `hello.txt`, then reads it back and prints the contents.

# %%
with open("hello.txt", "w") as f:
    f.write("Hello World")

with open("hello.txt", "r") as f:
    print(f.read())
# Out:
# Hello World

# %% [markdown]
# ## Q5. Data I/O
# Load the file `students.csv` (or create a small CSV yourself) with Pandas and show the first 5 rows.

# %%
with open("students.csv", "w") as f:
    f.write("name,grade\n")
    f.write("Liam,91\n")
    f.write("Zara,84\n")
    f.write("Noah,88\n")
    f.write("Mila,93\n")
    f.write("Kai,87\n")

import pandas as pd

df = pd.read_csv("students.csv")
df.head()
# Out:
#    name  grade
# 0  Liam     91
# 1  Zara     84
# 2  Noah     88
# 3  Mila     93
# 4   Kai     87

# %% [markdown]
# ## Q6. Plotting
# Create a line plot of $y = x^2$ for $x$ values from 0 to 10.

# %%
import matplotlib.pyplot as plt

x = list(range(11))
y = [i**2 for i in x]

plt.plot(x, y)
plt.show()

# %% [markdown]
# ## Q7. Shortcuts
# In Command mode, what keyboard shortcut deletes a cell?

# %% [markdown]
# *Your Answer:*
# Press D twice (DD)

# %% [markdown]
# ## Q8. Help and Docs
# Use `?` to display the docstring for `len`. Show the result.

# %%
len?
# Out:
# Signature: len(obj, /)
# Docstring: Return the number of items in a container.
# Type:      builtin_function_or_method

# %% [markdown]
# ## Q9. Timing
# Compare the runtime of squaring numbers using a Python loop vs. NumPy. Use `%timeit` for each.

# %%
import numpy as np

# %timeit [i**2 for i in range(10000)]

# %timeit np.arange(10000)**2
# Out:
# 348 μs ± 1.39 μs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 7.34 μs ± 411 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## Q10. Reflection
# Why is it useful to mix Markdown and code in Jupyter notebooks? Write 2–3 sentences.

# %% [markdown]
# *Your Answer:*
# Jupyter notebooks let you mix explanations with code in the same place. This makes it easier to understand what the code is doing and document the steps of the work. It is useful for learning, experimenting, and sharing results with others.
