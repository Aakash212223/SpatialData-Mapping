# %% [markdown]
# # 🎯 Notebook 04: Indexing and Selection
#
# Time to slice and dice.
#
# In this notebook, you'll:
# - Use `.loc[]` for label-based selection
# - Use `.iloc[]` for position-based selection
# - Create boolean masks to filter rows
# - Select specific columns and rows (solo or together)
#
# Let the chaos of index manipulation begin.
# ---

# %%
# !pip install seaborn
# Out:
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /Users/aakash/4543-5993-Spatial-Data/venv/lib/python3.13/site-packages (from seaborn) (2.4.2)
# Requirement already satisfied: pandas>=1.2 in /Users/aakash/4543-5993-Spatial-Data/venv/lib/python3.13/site-packages (from seaborn) (3.0.1)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /Users/aakash/4543-5993-Spatial-Data/venv/lib/python3.13/site-packages (from seaborn) (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/aakash/4543-5993-Spatial-Data/venv/lib/python3.13/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Users/aakash/4543-5993-Spatial-Data/venv/lib/python3.13/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/aakash/4543-5993-Spatial-Data/venv/lib/python3.13/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.62.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/aakash/4543-5993-Spatial-Data/venv/lib/python3.13/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /Users/aakash/4543-5993-Spatial-Data/venv/lib/python3.13/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (26.0)
# Requirement already satisfied: pillow>=8 in /Users/aakash/4543-5993-Spatial-Data/venv/lib/python3.13/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (12.1.1)
# Requirement already satisfied: pyparsing>=3 in /Users/aakash/4543-5993-Spatial-Data/venv/lib/python3.13/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/aakash/4543-5993-Spatial-Data/venv/lib/python3.13/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Users/aakash/4543-5993-Spatial-Data/venv/lib/python3.13/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2
#
# [notice] A new release of pip is available: 25.0 -> 26.1
# [notice] To update, run: pip install --upgrade pip

# %%
import pandas as pd
import seaborn as sns

# We'll use the Titanic dataset again
df = sns.load_dataset("titanic")
df.head(3)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True

# %% [markdown]
# ## 🔎 Select rows by label with `.loc[]`

# %%
# .loc[row_label, column_label]
# Titanic uses default RangeIndex, so labels are integers
print(df.loc[0])

# Row range (inclusive!)
df.loc[0:4, ["age", "fare", "sex"]]
# Out:
# survived                 0
# pclass                   3
# sex                   male
# age                   22.0
# sibsp                    1
# parch                    0
# fare                  7.25
# embarked                 S
# class                Third
# who                    man
# adult_male            True
# deck                   NaN
# embark_town    Southampton
# alive                   no
# alone                False
# Name: 0, dtype: object
#     age     fare     sex
# 0  22.0   7.2500    male
# 1  38.0  71.2833  female
# 2  26.0   7.9250  female
# 3  35.0  53.1000  female
# 4  35.0   8.0500    male

# %% [markdown]
# ## 🔢 Select rows by position with `.iloc[]`

# %%
# iloc uses pure positions
df.iloc[0]  # First row

# Row slice, column slice
df.iloc[1:4, 0:5]
# Out:
#    survived  pclass     sex   age  sibsp
# 1         1       1  female  38.0      1
# 2         1       3  female  26.0      0
# 3         1       1  female  35.0      1

# %% [markdown]
# ## 🎯 Boolean Masking (Filtering)

# %%
# Filter passengers under age 10
kids = df[df["age"] < 10]
kids[["age", "sex", "class"]].head()
# Out:
#     age     sex   class
# 7   2.0    male   Third
# 10  4.0  female   Third
# 16  2.0    male   Third
# 24  8.0  female   Third
# 43  3.0  female  Second

# %% [markdown]
# ## 🧠 Compound Conditions

# %%
# Adults in First Class who paid over $100
rich_folks = df[(df["age"] > 18) & (df["class"] == "First") & (df["fare"] > 100)]
rich_folks[["age", "class", "fare"]].head()
# Out:
#       age  class      fare
# 27   19.0  First  263.0000
# 88   23.0  First  263.0000
# 118  24.0  First  247.5208
# 195  58.0  First  146.5208
# 215  31.0  First  113.2750

# %% [markdown]
# ## 🧹 Select Columns Only

# %%
df[["sex", "age", "embarked"]].head()
# Out:
#       sex   age embarked
# 0    male  22.0        S
# 1  female  38.0        C
# 2  female  26.0        S
# 3  female  35.0        S
# 4    male  35.0        S

# %% [markdown]
# ## 🎯 Your Turn
#
# 1. Select the first row using `.iloc[]`, then again using `.loc[]`.
# 2. Slice the first 5 rows and select only `survived`, `sex`, and `age` columns.
# 3. Filter the dataset for female passengers over 40.
# 4. Create a DataFrame of passengers in 2nd class under age 15.
# 5. Use `.loc[]` to select the rows 10–20 and only the columns `fare`, `class`, and `age`.
#
# 🎯 **Bonus:** Find passengers with missing `age` and print only their `name`, `age`, and `pclass` (use `.isnull()`).

# %%
# Your slicing magic goes here!
df.iloc[0]
df.loc[0]

df.loc[0:4, ["survived", "sex", "age"]]

df[(df["sex"] == "female") & (df["age"] > 40)]

df[(df["pclass"] == 2) & (df["age"] < 15)]

df.loc[10:20, ["fare", "class", "age"]]

df.loc[10:20, ["fare", "class", "age"]]

df[df["age"].isnull()][["age", "pclass"]]
# Out:
#      age  pclass
# 5    NaN       3
# 17   NaN       2
# 19   NaN       3
# 26   NaN       3
# 28   NaN       3
# ..   ...     ...
# 859  NaN       3
# 863  NaN       3
# 868  NaN       3
# 878  NaN       3
# 888  NaN       3
#
# [177 rows x 2 columns]

# %% [markdown]
# ---
# ## 🧼 Why This Matters
#
# Being able to surgically select parts of your dataset is the core of real analysis. Whether you're cleaning junk or feeding a model, proper indexing = power.
#
# Next: cleaning your data with `.dropna()`, `.fillna()`, and more. The fun begins when you try to fix the stuff that's broken.
