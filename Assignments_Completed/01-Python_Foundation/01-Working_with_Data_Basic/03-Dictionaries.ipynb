# %% [markdown]
# # 📘 03 - Python Dictionaries
#
# Dictionaries store key-value pairs for fast lookups.

# %% [markdown]
# ## ✅ Learning Goals
# - Create and access dictionary items
# - Use dictionary methods like `.get()` and `.items()`

# %%
# 📚 Create a Dictionary
student = {'name': 'Alex', 'age': 21, 'major': 'CS'}
print(student)

# %%
# 🔍 Access Values
print(student['name'])
print(student.get('gpa', 'N/A'))

# %%
# 🔁 Loop Over Dictionary
for key, value in student.items():
    print(key, '->', value)

# %% [markdown]
# ## ✏️ Your Turn
# Create a dictionary to store information about your favorite book.

# %%
book = {'title': 'Harry Potter', 'author': 'J.K. Rowling', 'pages': 309, 'rating': 9}
print(book)

print(book['title'])
print(book.get('rating', 'no rating'))

for key, value in book.items():
    print(key, '->', value)
# Out:
# {'title': 'Harry Potter', 'author': 'J.K. Rowling', 'pages': 309, 'rating': 9}
# Harry Potter
# 9
# title -> Harry Potter
# author -> J.K. Rowling
# pages -> 309
# rating -> 9
